# %% [markdown]
# # Booleans
#  - Booleans represent one of two values: True or False

# %% [markdown]
# # Operator

# %% [markdown]
# ## Comparison Operators - 比較運算子
#   - Equals: a == b
#     - 5 = 5
#   - Not Equals: a != b
#     - 5 != 4
#   - Less than: a < b
#     - 3 < 5
#   - Less than or equal to: a <= b
#     - 6 <= 7
#     - 6 <= 6
#   - Greater than: a > b
#     - 7 > 5
#   - Greater than or equal to: a >= b
#     - 5 >= 4
#     - 5 >= 5

# %%
a=100
b=200

# (==) operator, checks if two operands are equal or not
print(a==b)

# (!=) operator, checks if two operands are not equal
print(a!=b)

# (>) operator, checks left operand is greater than right operand or not
print(a>b)

# (<) operator, checks left operand is less than right operand or not
print(a<b)
#(>=) operator, checks left operand is greater than or equal to right operand or not
print(a>=b)

# (<=) operator, checks left operand is less than or equal to right operand or not
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ## Logical Operators 邏輯運算子

# %%
x = True
y = False

print('x and y is',x and y)

print('x or y is',x or y)

print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %%
#take user input as int
a=int(input())

# logical AND operation

if a%4==0 and a%3==0:
    print("divided by both 4 and 3")

# logical OR operation
if a%4==0 or a%3==0:
    print("either divided by 4 or 3")

# logical NOT operation
if not(a%4==0 or a%3==0):
    print("neither divided by 4 nor 3")
# Out:
# 5
# neither divided by 4 nor 3

# %% [markdown]
# # If statement

# %% [markdown]
# ## if 條件判斷
#   - An "if statement" is written by using the if keyword.

# %%
# Error
a = 33
b = 200
if b > a:
print("b is greater than a") # you will get an error
# Out:
#   File "<ipython-input-1-b906152f3939>", line 5
#     print("b is greater than a") # you will get an error
#         ^
# IndentationError: expected an indented block

# %%
a = 33
b = 200
if b > a:
    print("b is greater than a") # Indentation 縮排(4個空格)
# Out:
# b is greater than a

# %%
# ch5_1.py
age = input("請輸入年齡: ")
if (int(age) < 20):
    print("你年齡太小")
    print("需年滿20歲才可以購買菸酒")
if (int(age) > 20):
    print("可以喝酒")
# Out:
# 請輸入年齡: 78
# 可以喝酒

# %%
# ch5_2_1.py
print("輸出絕對值")
num = input("請輸入任意整數值: ")
x = int(num)
if (int(x) < 0): x = abs(x)
print("絕對值是 %d" % int(x))

# %%
# ch5_2.py
print("輸出絕對值")
num = input("請輸入任意整數值: ")
x = int(num)
if (int(x) < 0):
    x = abs(x)
print("絕對值是 %d" % int(x))

# %% [markdown]
# ## If - else statement - else
#   - The else keyword catches anything which isn't caught by the preceding conditions.

# %%
a = 33
b = 200
if b > a:
  print(b)
else:
  print(a)
# Out:
# 200

# %%
# ch5_3.py
age = input("請輸入年齡: ")
if (int(age) < 20):
    print("你年齡太小")
    print("需年滿20歲才可以購買菸酒")
else:
    print("歡迎購買菸酒")

# %%
# ch5_4.py
print("奇數偶數判斷")
num = input("請輸入任意整值: ")
rem = int(num) % 2
if (rem == 0):
    print("%d 是偶數" % int(num))
else:
    print("%d 是奇數" % int(num))

# %% [markdown]
# ## If ... elif ... else statement - elif
#   - The elif keyword is pythons way of saying "if the previous conditions were not true, then try this condition".

# %%
# ch5_5.py
print("計算最終成績")
score = input("請輸入分數: ")
sc = int(score)
if (sc >= 90):
    print(" A")
elif (sc >= 80):
    print(" B")
elif (sc >= 70):
    print(" C")
elif (sc >= 60):
    print(" D")
else:
    print(" F")

# %%
sco = input("輸入分數")
score = int(sco)

if score == 100:
    print('特優')
elif score >= 90:
    print('優')
elif score >= 80:
    print('佳')
elif score >= 70:
    print('好')
elif score >= 60:
    print('良')
else:
    print('劣')

# %%
# ch5_6.py
print("計算票價")
age = input("請輸入年齡: ")
age = int(age)
ticket = 100
if age >= 80 or age <= 6:
    ticket = ticket * 0.2
    print("票價是: %d" % ticket)
elif age >= 60 or age <= 12:
    ticket = ticket * 0.5
    print("票價是: %d" % ticket)
else:
    print("票價是: %d" % ticket)

# %%
# ch5_6_1.py
print("計算票價")
age = input("請輸入年齡: ")
age = int(age)
ticket = 100
if (age >= 80) or (age <= 6):
    ticket = ticket * 0.2
    print("票價是: %d" % ticket)
elif (age >= 60) or (age <= 12):
    ticket = ticket * 0.5
    print("票價是: %d" % ticket)
else:
    print("票價是: %d" % ticket)

# %%
# ch5_7.py
print("判斷輸入字元類別")
ch = input("請輸入字元: ")
if ord(ch) >= ord("A") and ord(ch) <= ord("Z"):
    print("這是大寫字元")
elif ord(ch) >= ord("a") and ord(ch) <= ord("z"):
    print("這是小寫字元")
elif ord(ch) >= ord("0") and ord(ch) <= ord("9"):
    print("這是數字")
else:
    print("這是特殊字元")

# %% [markdown]
# ## Nested If - 巢狀if

# %%
# ch5_8.py Basic36 平、閏年判定
print("判斷輸入年份是否潤年")
year = input("請輸入年分: ")
rem4 = int(year) % 4
rem100 = int(year) % 100
rem400 = int(year) % 400
if rem4 == 0:
    if rem100 != 0 or rem400 == 0:
        print("%s 是潤年" % year)
    else:
        print("%s 不是潤年" % year)
else:
    print("%s 不是潤年" % year)

# %% [markdown]
# # Practice - 練習

# %%
# BMI 計算
weight=float(input('請輸入你的體重（公斤）:'))
high=float(input('請輸入你的身高（公分）:'))
bmi = (weight // ((high /100) ** 2))
 
print("你的身高和體重分別是：{0} CM,{1} KG".format(high,weight))
print ('您的BMI指數為：{0:.2f}'.format(bmi))
 
if bmi < 18.5:
	print('體重過輕')
elif bmi >=18.5 and bmi <24:
	print('正常範圍')
elif bmi >=24 and bmi < 27:
	print('過重')
elif bmi >=24 and bmi < 27:
	print('輕度肥胖')   
elif bmi >=30 and bmi < 35:
	print('中度肥胖')
else:
	print('嚴重肥胖')

# %%
# 12生肖系統
year = eval(input("請輸入西元出生年 : "))
year -= 1900
zodiac = year % 12
if zodiac == 0:
    print("你是生肖是 : 鼠")
elif zodiac == 1:
    print("你是生肖是 : 牛")
elif zodiac == 2:
    print("你是生肖是 : 虎")
elif zodiac == 3:
    print("你是生肖是 : 兔")
elif zodiac == 4:
    print("你是生肖是 : 龍")
elif zodiac == 5:
    print("你是生肖是 : 蛇")
elif zodiac == 6:
    print("你是生肖是 : 馬")
elif zodiac == 7:
    print("你是生肖是 : 羊")
elif zodiac == 8:
    print("你是生肖是 : 猴")
elif zodiac == 9:
    print("你是生肖是 : 雞")
elif zodiac == 10:
    print("你是生肖是 : 狗")
else:
    print("你是生肖是 : 豬")

# %%
# 打工薪資計算
salary=input("請輸入工作時數(單位:小時) : ")
x=int(salary)#薪資
if(x < 120):#小於120小時的薪資
    x = (150 * x) +(150 * x * 0.8)  #底薪成長0.8倍
    print("打工薪資為: %d " % x)
elif(x == 120):#120小時的薪資
    x = (150 * x) + (150 * x * 1.0) #底薪成長1倍
    print("打工薪資為: %d " % x)
elif(x <=150): #小於150小時的薪資
    x = (150 * x) + (150 * x * 1.2) #底薪成長1.2倍
    print("打工薪資為: %d " % x)
else:#150小時以上的薪資
    x = (150 * x) + (150 * x * 1.6) #底薪成長1.6倍
    print("打工薪資為: %d " % x)

# %%
# 限用 Python 3.8 
salary=input("請輸入工作時數(單位:小時) : ")
#x=int(salary)#薪資
if((x := int(salary)) < 120):#小於120小時的薪資
    x = (150 * x) +(150 * x * 0.8)  #底薪成長0.8倍
    print("打工薪資為: %d " % x)
elif(x == 120):#120小時的薪資
    x = (150 * x) + (150 * x * 1.0) #底薪成長1倍
    print("打工薪資為: %d " % x)
elif(x <=150): #小於150小時的薪資
    x = (150 * x) + (150 * x * 1.2) #底薪成長1.2倍
    print("打工薪資為: %d " % x)
else:#150小時以上的薪資
    x = (150 * x) + (150 * x * 1.6) #底薪成長1.6倍
    print("打工薪資為: %d " % x)

# %%
# Basic 3 判斷座標是否在圓形的範圍內
import math

x = int(input(""))
y = int(input(""))

if math.sqrt(x*x+y*y <= 200):
    print("inside")
else:
    print("outside")

# %%
# Basic 6 季節判定
Mon = input("")
Month = int(Mon)

if Month >=3 and Month <=5:
    print("Spring")
elif Month >=6 and Month <=8:
    print("Summer")
elif Month >=9 and Month <=11:
    print("Autumn")
else:
    print("Winter")
